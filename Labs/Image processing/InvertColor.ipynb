# %%
from PIL import Image

# %%
path = "avatar.jpg"
img = Image.open(path)

# %%
width , height = img.size

# %%
width , height
# Out:
# (400, 400)

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F851E028320>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F851E028320>

# %%
newimg = Image.new("RGB",(width,height),"white")
for i in range(1,width-1):
    for j in range(1,height-1):
# Out:
#   File "<ipython-input-15-2d73c46769e4>", line 5
#
#     ^
# SyntaxError: unexpected EOF while parsing
