# %%
import socket
from urllib.parse import quote_plus
cabecera = """\
GET /maps/api/geocode/json?address={}&sensor=false HTTP/1.1\r\n\
Host: maps.google.com:80\r\n\
User-Agent:  \r\n\
Connection: close\r\n\
\r\n\
"""
def localizar(direccion):
    conexion = socket.socket()
    conexion.connect(('maps.google.com', 80))
    cabeceraAux = cabecera.format(quote_plus(direccion))
    conexion.sendall(cabeceraAux.encode('utf-8'))
 
    datos = b''
    d = conexion.recv(1024)
    while d:
         datos += d
         d = conexion.recv(1024)
 
    print(datos.decode('utf-8'))
 
 
if __name__ == '__main__':
    address = input("Direccion: ")
    localizar(address)
# Out:
# Direccion: ovalo cabitos
# HTTP/1.1 200 OK
# Content-Type: application/json; charset=UTF-8
# Date: Wed, 23 Aug 2017 22:03:34 GMT
# Expires: Thu, 24 Aug 2017 22:03:34 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
# Connection: close
#
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Avenida Aviación",
#                "short_name" : "Av. Aviación",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Higuereta",
#                "short_name" : "Higuereta",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Santiago de Surco",
#                "short_name" : "Santiago de Surco",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Provincia de Lima",
#                "short_name" : "Provincia de Lima",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Peru",
#                "short_name" : "PE",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "15038",
#                "short_name" : "15038",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Av. Aviación, Santiago de Surco 15038, Peru",
#          "geometry" : {
#             "location" : {
#                "lat" : -12.1273988,
#                "lng" : -77.00048889999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -12.1260498197085,
#                   "lng" : -76.9991399197085
#                },
#                "southwest" : {
#                   "lat" : -12.1287477802915,
#                   "lng" : -77.0018378802915
#                }
#             }
#          },
#          "place_id" : "ChIJ0bjaa_jHBZER9jmX2-BxAuk",
#          "types" : [
#             "establishment",
#             "point_of_interest",
#             "subway_station",
#             "transit_station"
#          ]
#       }
#    ],
#    "status" : "OK"
# }
