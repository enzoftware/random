# %%
from bs4 import BeautifulSoup
import requests

__author__ = 'enzoftware'

url = "https://github.com/enzoftware?tab=repositories" # Cambiar por el repositpr
req = requests.get(url)
status_code = req.status_code
html_text = req.text

# %%
print(status_code)
# Out:
# 200

# %%
print(html_text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://assets-cdn.github.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-bedfc518345498ab3204d330c1727cde7e733526a09cd7df6867f6a231565091.css" media="all" rel="stylesheet" />
#   <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-7fe2b92304082e7579ea9aaf717b05ebef9288ada19f3ff3afeca11b72e5f4aa.css" media="all" rel="stylesheet" />
#
#
# ...

# %%
if status_code == 200 :
    #Pasar a un objeto BS
    html = BeautifulSoup(html_text,"html.parser")
    
    #Obtenemos las etiquetas deseadas
    entradas = html.find_all('li',{'itemprop':'owns'})
    
    #Recorremos toda la data para obtener lo deseado
    for i, entrada in enumerate(entradas):
        #Con getText() , devuelve el HTML
        repo_name = entrada.find('a',{'itemprop':'name codeRepository'}).getText()
        descripcion = entrada.find('p',{'itemprop':'description'})
        language = entrada.find('span',{'itemprop':'programmingLanguage'}).getText()
        
        if(descripcion.getText() == None):
            descripcion = 'Empty'
        
        #Imprime la data obtenida
        print(i+1,repo_name,descripcion.getText(),language)
else:
    print("Status code",status_code)
# Out:
# 1
#         soccer-freestyle
#           Clone of Facebook messenger mini-game about soccer freestyle ⚽️
#
#           Kotlin
#
# 2
#         pokedex-enzoftware
#           Pokedex demo with PokeAPI data and Retrofit
#
#           Java
#
# 3
#         sentiment-analysis
#           Sentiment analysis app build with Node.js , Express , sentiment and ntwitter
#
#           JavaScript
#
# 4
#         how-to-think-like-a-computer-scientist
#           Do you love computer science? Do you want to know more? Do you want to learn python? This repository is for you 😄
#
#           Jupyter Notebook
#
# 5
#         yoTeElijo
#           Aplicación para calificar a los profesores de la UPC
#
#           HTML
#
# 6
#         bomberman-upc
#           Bomberman game for algorithms and data structure class CC68. Develop by @enzoftware , @daztery and @RodrigoAGM
#
#           C++
#
# 7
#         solar-system-animation
#           Astronomy animation made in Python ❤️ 🐍
#
#           Python
#
# 8
# ...

# %%
# print(entradas)
# Descomenta para ver el contenido de 'entradas'
